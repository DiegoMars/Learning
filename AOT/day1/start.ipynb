# %%
import pandas as pd
from pandasql import sqldf
df = pd.read_csv('data.csv')
df1 = pd.read_csv('data2.csv')
df.set_index('id',inplace=True)

# %%
sqldf("select first_name, email, loyalty_status from df;")
# Out:
#      first_name                                     email loyalty_status
# 0          Rice          Rice.Shinton@datascience.aot.com           None
# 1      Anatollo       Anatollo.Dinjes@datascience.aot.com           None
# 2      Giuseppe      Giuseppe.Woosnam@datascience.aot.com         Silver
# 3      Beatrice      Beatrice.Delafoy@datascience.aot.com           None
# 4      Bethanne  Bethanne.Adamthwaite@datascience.aot.com         Silver
# ...         ...                                       ...            ...
# 1495        Mel             Mel.Weich@datascience.aot.com           Gold
# 1496    Forster        Forster.Levins@datascience.aot.com           Gold
# 1497      Terra         Terra.Nutbeam@datascience.aot.com           Gold
# 1498       Viki          Viki.Creasey@datascience.aot.com         Silver
# 1499    Brendan        Brendan.McClay@datascience.aot.com           None
#
# [1500 rows x 3 columns]

# %%
df_append = pd.concat([df,df1], ignore_index=True)
df_append
# Out:
#      first_name    last_name                                     email  \
# 0          Rice      Shinton          Rice.Shinton@datascience.aot.com
# 1      Anatollo       Dinjes       Anatollo.Dinjes@datascience.aot.com
# 2      Giuseppe      Woosnam      Giuseppe.Woosnam@datascience.aot.com
# 3      Beatrice      Delafoy      Beatrice.Delafoy@datascience.aot.com
# 4      Bethanne  Adamthwaite  Bethanne.Adamthwaite@datascience.aot.com
# ...         ...          ...                                       ...
# 2995      Ferdy       Harrad          Ferdy.Harrad@datascience.aot.com
# 2996      Vanya      Caulket         Vanya.Caulket@datascience.aot.com
# 2997     Emalee        Folke          Emalee.Folke@datascience.aot.com
# 2998     Lorine     Matyukon       Lorine.Matyukon@datascience.aot.com
# 2999       Otes       Linton           Otes.Linton@datascience.aot.com
#
#         gender loyalty_status            education average_spend_2021  \
# ...
